# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.utils.data
from torch.autograd import Variable

# %%
movies = pd.read_csv('movies.dat',sep='::',header=None,engine='python',encoding = 'latin-1')

# %%
users = pd.read_csv('users.dat',sep='::',header=None,engine='python',encoding = 'latin-1')
print(users)
# Out:
#          0  1   2   3      4
# 0        1  F   1  10  48067
# 1        2  M  56  16  70072
# 2        3  M  25  15  55117
# 3        4  M  45   7  02460
# 4        5  M  25  20  55455
# 5        6  F  50   9  55117
# 6        7  M  35   1  06810
# 7        8  M  25  12  11413
# 8        9  M  25  17  61614
# 9       10  F  35   1  95370
# 10      11  F  25   1  04093
# 11      12  M  25  12  32793
# 12      13  M  45   1  93304
# 13      14  M  35   0  60126
# 14      15  M  25   7  22903
# 15      16  F  35   0  20670
# 16      17  M  50   1  95350
# 17      18  F  18   3  95825
# 18      19  M   1  10  48073
# 19      20  M  25  14  55113
# 20      21  M  18  16  99353
# 21      22  M  18  15  53706
# 22      23  M  35   0  90049
# 23      24  F  25   7  10023
# 24      25  M  18   4  01609
# 25      26  M  25   7  23112
# 26      27  M  25  11  19130
# 27      28  F  25   1  14607
# 28      29  M  35   7  33407
# 29      30  F  35   7  19143
# ...    ... ..  ..  ..    ...
# 6010  6011  M  35  15  80538
# 6011  6012  M  35  15  02871
# 6012  6013  F  25  20  32301
# 6013  6014  M  45   1  80634
# 6014  6015  F  25   9  80013
# 6015  6016  M  45   1  37209
# 6016  6017  F  35   7  21117
# 6017  6018  M  35   1  48906
# 6018  6019  M  25   0  10024
# 6019  6020  M  50  16  10023
# 6020  6021  M  25  12  08876
# 6021  6022  M  25  17  57006
# 6022  6023  M  25   0  43213
# 6023  6024  M  25  12  53705
# 6024  6025  F  25   1  32607
# 6025  6026  M  35   6  11210
# 6026  6027  M  18   4  20742
# 6027  6028  M  18   4  94133
# 6028  6029  F  25   1  23185
# 6029  6030  M  25  17  32618
# 6030  6031  F  18   0  45123
# 6031  6032  M  45   7  55108
# 6032  6033  M  50  13  78232
# 6033  6034  M  25  14  94117
# 6034  6035  F  25   1  78734
# 6035  6036  F  25  15  32603
# 6036  6037  F  45   1  76006
# 6037  6038  F  56   1  14706
# 6038  6039  F  45   0  01060
# 6039  6040  M  25   6  11106
#
# [6040 rows x 5 columns]

# %%
ratings = pd.read_csv('ratings.dat',sep='::',header=None,engine='python',encoding = 'latin-1')

# %%
#Preparing the training set and the test set
tr_set= pd.read_csv('u1.base',delimiter='\t')
tr_set=np.array(tr_set,dtype='int')
te_set= pd.read_csv('u1.test',delimiter='\t')
te_set=np.array(tr_set,dtype='int')

# %%
#getting the numbers of users and movies
nb_users=int(max(max(tr_set[:,0]),max(te_set[:,0])))
nb_movies=int(max(max(tr_set[:,1]),max(te_set[:,1])))

# %%
#Converting the data into an array with users in lines and movies in columns
def convert(data):
    new_data=[]
    for id_users in range(1,nb_users+1):
        id_movies=data[:,1][data[:,0]==id_users]
        id_ratings=data[:,2][data[:,0]==id_users]
        ratings=np.zeros(nb_movies)
        ratings[id_movies-1] = id_ratings
        new_data.append(list(ratings))
    return new_data
tr_set=convert(tr_set)
te_set=convert(te_set)

# %%
#Converting the data into torch sensors
tr_set = torch.FloatTensor(tr_set)
te_set=torch.FloatTensor(te_set)

# %%
#Creating the architecture of the neural network
class SAE(nn.Module):
    def __init__(self,):
        super(SAE, self).__init__()
        self.fc1 = nn.Linear(nb_movies, 20)
        self.fc2 = nn.Linear(20,10)
        self.fc3 = nn.Linear(10,20)
        self.fc4 = nn.Linear(20,nb_movies)
        self.activation = nn.Sigmoid()
    def forward(self, x):
        x = self.activation(self.fc1(x))
        x = self.activation(self.fc2(x))
        x = self.activation(self.fc3(x))
        x = self.fc4(x)
        return x
sae = SAE()
criterion = nn.MSELoss()
optimizer = optim.RMSprop(sae.parameters(), lr = 0.01, weight_decay = 0.5)

# %%
import torch.tensor as tf
#Training the SAE
nb_epoch = 200
for epoch in range (1, nb_epoch +1):
    train_loss = 0
    s=0.
    for id_user in range(nb_users):
        input = Variable(tr_set[id_user]).unsqueeze(0)
        target = input.clone()
        if torch.sum(target.data > 0) > 0:
            output = sae(input)
            target.require_grad = False
            output[target == 0] = 0
            loss = criterion(output, target)
            mean_corrector = nb_movies/float(torch.sum(target.data>0) + 1e-10)
            loss.backward()
            train_loss += np.sqrt(loss.data*mean_corrector)
            s += 1.
            optimizer.step()
    print('epoch: '+str(epoch)+' loss'+str(train_loss/s))
# Out:
# epoch: 1 losstensor(1.7712)
# epoch: 2 losstensor(1.0967)
# epoch: 3 losstensor(1.0534)
# epoch: 4 losstensor(1.0386)
# epoch: 5 losstensor(1.0310)
# epoch: 6 losstensor(1.0266)
# epoch: 7 losstensor(1.0239)
# epoch: 8 losstensor(1.0219)
# epoch: 9 losstensor(1.0207)
# epoch: 10 losstensor(1.0196)
# epoch: 11 losstensor(1.0189)
# epoch: 12 losstensor(1.0184)
# epoch: 13 losstensor(1.0178)
# epoch: 14 losstensor(1.0173)
# epoch: 15 losstensor(1.0172)
# epoch: 16 losstensor(1.0171)
# epoch: 17 losstensor(1.0168)
# epoch: 18 losstensor(1.0164)
# epoch: 19 losstensor(1.0165)
# epoch: 20 losstensor(1.0160)
# epoch: 21 losstensor(1.0163)
# epoch: 22 losstensor(1.0160)
# epoch: 23 losstensor(1.0158)
# epoch: 24 losstensor(1.0159)
# epoch: 25 losstensor(1.0156)
# epoch: 26 losstensor(1.0157)
# epoch: 27 losstensor(1.0155)
# epoch: 28 losstensor(1.0150)
# epoch: 29 losstensor(1.0124)
# epoch: 30 losstensor(1.0118)
# epoch: 31 losstensor(1.0094)
# epoch: 32 losstensor(1.0090)
# epoch: 33 losstensor(1.0055)
# epoch: 34 losstensor(1.0056)
# epoch: 35 losstensor(1.0009)
# epoch: 36 losstensor(1.0011)
# epoch: 37 losstensor(0.9985)
# epoch: 38 losstensor(0.9973)
# epoch: 39 losstensor(0.9949)
# epoch: 40 losstensor(0.9954)
# epoch: 41 losstensor(0.9912)
# epoch: 42 losstensor(0.9903)
# epoch: 43 losstensor(0.9880)
# epoch: 44 losstensor(0.9890)
# epoch: 45 losstensor(0.9866)
# epoch: 46 losstensor(0.9847)
# epoch: 47 losstensor(0.9830)
# epoch: 48 losstensor(0.9833)
# epoch: 49 losstensor(0.9770)
# epoch: 50 losstensor(0.9762)
# epoch: 51 losstensor(0.9749)
# epoch: 52 losstensor(0.9759)
# epoch: 53 losstensor(0.9714)
# epoch: 54 losstensor(0.9725)
# epoch: 55 losstensor(0.9690)
# epoch: 56 losstensor(0.9699)
# epoch: 57 losstensor(0.9643)
# epoch: 58 losstensor(0.9657)
# epoch: 59 losstensor(0.9628)
# epoch: 60 losstensor(0.9659)
# epoch: 61 losstensor(0.9627)
# epoch: 62 losstensor(0.9583)
# epoch: 63 losstensor(0.9575)
# epoch: 64 losstensor(0.9588)
# epoch: 65 losstensor(0.9536)
# epoch: 66 losstensor(0.9551)
# epoch: 67 losstensor(0.9509)
# epoch: 68 losstensor(0.9517)
# epoch: 69 losstensor(0.9489)
# epoch: 70 losstensor(0.9520)
# epoch: 71 losstensor(0.9496)
# epoch: 72 losstensor(0.9525)
# epoch: 73 losstensor(0.9512)
# epoch: 74 losstensor(0.9532)
# epoch: 75 losstensor(0.9464)
# epoch: 76 losstensor(0.9489)
# epoch: 77 losstensor(0.9447)
# epoch: 78 losstensor(0.9459)
# epoch: 79 losstensor(0.9437)
# epoch: 80 losstensor(0.9443)
# epoch: 81 losstensor(0.9416)
# epoch: 82 losstensor(0.9424)
# epoch: 83 losstensor(0.9405)
# epoch: 84 losstensor(0.9412)
# epoch: 85 losstensor(0.9394)
# epoch: 86 losstensor(0.9397)
# epoch: 87 losstensor(0.9383)
# epoch: 88 losstensor(0.9387)
# epoch: 89 losstensor(0.9370)
# epoch: 90 losstensor(0.9377)
# epoch: 91 losstensor(0.9356)
# epoch: 92 losstensor(0.9364)
# epoch: 93 losstensor(0.9349)
# epoch: 94 losstensor(0.9353)
# epoch: 95 losstensor(0.9341)
# epoch: 96 losstensor(0.9348)
# epoch: 97 losstensor(0.9337)
# epoch: 98 losstensor(0.9339)
# epoch: 99 losstensor(0.9327)
# epoch: 100 losstensor(0.9334)
# epoch: 101 losstensor(0.9322)
# epoch: 102 losstensor(0.9324)
# epoch: 103 losstensor(0.9315)
# epoch: 104 losstensor(0.9319)
# epoch: 105 losstensor(0.9308)
# epoch: 106 losstensor(0.9312)
# epoch: 107 losstensor(0.9302)
# epoch: 108 losstensor(0.9304)
# epoch: 109 losstensor(0.9296)
# epoch: 110 losstensor(0.9297)
# epoch: 111 losstensor(0.9286)
# epoch: 112 losstensor(0.9290)
# epoch: 113 losstensor(0.9286)
# epoch: 114 losstensor(0.9285)
# epoch: 115 losstensor(0.9279)
# epoch: 116 losstensor(0.9275)
# epoch: 117 losstensor(0.9273)
# epoch: 118 losstensor(0.9275)
# epoch: 119 losstensor(0.9265)
# epoch: 120 losstensor(0.9269)
# epoch: 121 losstensor(0.9259)
# epoch: 122 losstensor(0.9261)
# epoch: 123 losstensor(0.9255)
# epoch: 124 losstensor(0.9256)
# epoch: 125 losstensor(0.9249)
# epoch: 126 losstensor(0.9251)
# epoch: 127 losstensor(0.9244)
# epoch: 128 losstensor(0.9246)
# epoch: 129 losstensor(0.9238)
# epoch: 130 losstensor(0.9238)
# epoch: 131 losstensor(0.9233)
# epoch: 132 losstensor(0.9233)
# epoch: 133 losstensor(0.9229)
# epoch: 134 losstensor(0.9228)
# epoch: 135 losstensor(0.9220)
# epoch: 136 losstensor(0.9223)
# epoch: 137 losstensor(0.9218)
# epoch: 138 losstensor(0.9217)
# epoch: 139 losstensor(0.9214)
# epoch: 140 losstensor(0.9215)
# epoch: 141 losstensor(0.9209)
# epoch: 142 losstensor(0.9209)
# epoch: 143 losstensor(0.9207)
# epoch: 144 losstensor(0.9205)
# epoch: 145 losstensor(0.9200)
# epoch: 146 losstensor(0.9203)
# epoch: 147 losstensor(0.9195)
# epoch: 148 losstensor(0.9198)
# epoch: 149 losstensor(0.9190)
# epoch: 150 losstensor(0.9191)
# epoch: 151 losstensor(0.9183)
# epoch: 152 losstensor(0.9184)
# epoch: 153 losstensor(0.9182)
# epoch: 154 losstensor(0.9185)
# epoch: 155 losstensor(0.9179)
# epoch: 156 losstensor(0.9178)
# epoch: 157 losstensor(0.9177)
# epoch: 158 losstensor(0.9176)
# epoch: 159 losstensor(0.9172)
# epoch: 160 losstensor(0.9170)
# epoch: 161 losstensor(0.9170)
# epoch: 162 losstensor(0.9168)
# epoch: 163 losstensor(0.9164)
# epoch: 164 losstensor(0.9163)
# epoch: 165 losstensor(0.9161)
# epoch: 166 losstensor(0.9160)
# epoch: 167 losstensor(0.9157)
# epoch: 168 losstensor(0.9157)
# epoch: 169 losstensor(0.9155)
# epoch: 170 losstensor(0.9152)
# epoch: 171 losstensor(0.9150)
# epoch: 172 losstensor(0.9150)
# epoch: 173 losstensor(0.9147)
# epoch: 174 losstensor(0.9147)
# epoch: 175 losstensor(0.9146)
# epoch: 176 losstensor(0.9146)
# epoch: 177 losstensor(0.9144)
# epoch: 178 losstensor(0.9144)
# epoch: 179 losstensor(0.9139)
# epoch: 180 losstensor(0.9139)
# epoch: 181 losstensor(0.9135)
# epoch: 182 losstensor(0.9137)
# epoch: 183 losstensor(0.9133)
# epoch: 184 losstensor(0.9133)
# epoch: 185 losstensor(0.9131)
# epoch: 186 losstensor(0.9132)
# epoch: 187 losstensor(0.9130)
# epoch: 188 losstensor(0.9128)
# epoch: 189 losstensor(0.9128)
# epoch: 190 losstensor(0.9125)
# epoch: 191 losstensor(0.9125)
# epoch: 192 losstensor(0.9122)
# epoch: 193 losstensor(0.9120)
# epoch: 194 losstensor(0.9119)
# epoch: 195 losstensor(0.9117)
# epoch: 196 losstensor(0.9116)
# epoch: 197 losstensor(0.9116)
# epoch: 198 losstensor(0.9113)
# epoch: 199 losstensor(0.9113)
# epoch: 200 losstensor(0.9114)

# %%
#testing the SAE
test_loss = 0
s=0.
for id_user in range(nb_users):
    input = Variable(tr_set[id_user]).unsqueeze(0)
    target = Variable(te_set[id_user])
    if torch.sum(target.data > 0) > 0:
        output = sae(input)
        target.require_grad = False
        output[target == 0] = 0
        loss = criterion(output, target)
        mean_corrector = nb_movies/float(torch.sum(target.data>0) + 1e-10)
        test_loss += np.sqrt(loss.data*mean_corrector)
        s += 1.
        optimizer.step()
print('epoch: '+str(epoch)+' loss'+str(test_loss/s))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-a569410eb808> in <module>()
#       8         output = sae(input)
#       9         target.require_grad = False
# ---> 10         output[target == 0] = 0
#      11         loss = criterion(output, target)
#      12         mean_corrector = nb_movies/float(torch.sum(target.data>0) + 1e-10)
#
# IndexError: The shape of the mask [1682] at index 0does not match the shape of the indexed tensor [1, 1682] at index 0
